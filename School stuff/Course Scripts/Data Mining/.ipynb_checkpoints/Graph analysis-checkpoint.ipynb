# %% [markdown]
# #### Important note: due to some reason, some visual results are not visible here that is why i uploaded the screenshot of the images by using IPython.display library, also all images are available in the provided word file.

# %%
# !pip install --upgrade --user pixiedust
#restart kernel now!

# %%
import pixiedust
#restart kernel now!

# %%
# !wget --show-progress 'https://d3js.org/d3.v3.js'

from IPython.core.display import HTML
HTML('<script src="d3.v3.js"></script>')
# Out:
# --2021-04-16 12:11:10--  https://d3js.org/d3.v3.js
# Resolving d3js.org (d3js.org)... 104.26.6.30, 172.67.73.126, 104.26.7.30, ...
# Connecting to d3js.org (d3js.org)|104.26.6.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/javascript]
# Saving to: ‘d3.v3.js’
#
# d3.v3.js                [ <=>                ] 330.02K  --.-KB/s    in 0.03s
#
# 2021-04-16 12:11:10 (10.3 MB/s) - ‘d3.v3.js’ saved [337945]
# <script src="d3.v3.js"></script>

# %%
import lxml

# %% [markdown]
# # 1. Graphs and PageRank algorithm

# %% [markdown]
# ## Task 1

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'


import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython.display import HTML

# Create a Vertex DataFrame with unique ID column "id"
v = sqlContext.createDataFrame([
  ("a", "Aval"),
  ("b", "Bval"),
  ("c", "Cval"),
  ("d", "Dval"),
], ["id", "value"])
# Create an Edge DataFrame with "src" and "dst" columns
e = sqlContext.createDataFrame([
  ("a", "b", 1),
  ("a", "c", 1),
  ("a", "d", 1),
  ("b", "a", 1),
  ("b", "d", 1), 
  ("c", "a", 1),
  ("d", "b", 1),
  ("d", "c", 1),
], ["src", "dst", "somevalue"])
# Create a GraphFrame
import pixiedust
from graphframes import *
g = GraphFrame(v, e)

display(g)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style class="pd_save is-viewer-good">
#     .node circle {
#         fill: #fff;
#         stroke: steelblue;
#         stroke-width: 1.5px;
#     }
#     .node {
#         font: 10px sans-serif;
#     }
#
#     .link {
#         fill: none;
#         stroke: #ccc;
#         stroke-width: 1.5px;
#     }
#
#     .graph-tree-form.form-inline .form-group {
#         margin-right: 10px;
#     }
#     .graph-tree-form.form-inline .form-group:last-child {
#         margin-left: 40px;
#     }
#     .graph-tree-form.form-inline input,
#     .graph-tree-form.form-inline select,
#     .graph-tree-form.form-inline button {
#         border-radius: 0;
#         margin: 0;
#         width: 100%;
#     }
#     .graph-error {
#         color: red;
#         font-weight: 500;
# ...

# %%
from IPython.display import Image
Image(filename='task1_1.PNG')

# %% [markdown]
# ## Task 2

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'

import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %%
# Run PageRank algorithm, and show results.
for resetProbability in [0.2, 0.01,0.0001]:
    print ('Results of resetProbability = {} '.format(resetProbability))
    results = g.pageRank(resetProbability=resetProbability, maxIter=40)
    results.vertices.select("id", "pagerank").sort("id").show()
# Out:
# Results of resetProbability = 0.2
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a|1.2857142857142856|
# |  b|0.9047619047619047|
# |  c|0.9047619047619047|
# |  d|0.9047619047619047|
# +---+------------------+
#
# Results of resetProbability = 0.01
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a|1.3311036789295645|
# |  b|0.8896321070234786|
# |  c|0.8896321070234786|
# |  d|0.8896321070234786|
# +---+------------------+
#
# Results of resetProbability = 0.0001
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a| 1.333311110370044|
# |  b|0.8888962965433188|
# |  c|0.8888962965433188|
# |  d|0.8888962965433188|
# +---+------------------+

# %% [markdown]
# ##### Comment for task 2

# %% [markdown]
# Yes the pagerank changed when we set different resetProbability values. for example, id a is 1.2758 when the resetProbability is set to 0.2. and it is 1.3311 for resetprobability 0.01 and 1.3333 for resetprobablity 0.0001

# %% [markdown]
# ## Task 3

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'

import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %%
from IPython.display import HTML

# Create a Vertex DataFrame with unique ID column "id"
v = sqlContext.createDataFrame([
  ("a", "Aval"),
  ("b", "Bval"),
  ("c", "Cval"),
  ("d", "Dval"),
], ["id", "value"])
# Create an Edge DataFrame with "src" and "dst" columns
e = sqlContext.createDataFrame([
  ("a", "b", 1),
  ("a", "c", 1),
  ("a", "d", 1),
  ("b", "a", 1),
  ("b", "d", 1), 
  #("c", "a", 1),
  ("d", "b", 1),
  ("d", "c", 1),
], ["src", "dst", "somevalue"])
# Create a GraphFrame
import pixiedust
from graphframes import *
g = GraphFrame(v, e)

display(g)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style class="pd_save is-viewer-good">
#     .node circle {
#         fill: #fff;
#         stroke: steelblue;
#         stroke-width: 1.5px;
#     }
#     .node {
#         font: 10px sans-serif;
#     }
#
#     .link {
#         fill: none;
#         stroke: #ccc;
#         stroke-width: 1.5px;
#     }
#
#     .graph-tree-form.form-inline .form-group {
#         margin-right: 10px;
#     }
#     .graph-tree-form.form-inline .form-group:last-child {
#         margin-left: 40px;
#     }
#     .graph-tree-form.form-inline input,
#     .graph-tree-form.form-inline select,
#     .graph-tree-form.form-inline button {
#         border-radius: 0;
#         margin: 0;
#         width: 100%;
#     }
#     .graph-error {
#         color: red;
#         font-weight: 500;
# ...

# %%
Image(filename='task1_3.PNG')

# %%
# Run PageRank algorithm, and show results.
for resetProbability in [0.2, 0.01,0.0001]:
    print ('Results of resetProbability = {} '.format(resetProbability))
    results = g.pageRank(resetProbability=resetProbability, maxIter=40)
    results.vertices.select("id", "pagerank").sort("id").show()
# Out:
# Results of resetProbability = 0.2
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a|0.8333333332923154|
# |  b|1.0555555555692282|
# |  c|1.0555555555692282|
# |  d|1.0555555555692282|
# +---+------------------+
#
# Results of resetProbability = 0.01
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a| 0.801599932593953|
# |  b|1.0661333558020158|
# |  c|1.0661333558020158|
# |  d|1.0661333558020158|
# +---+------------------+
#
# Results of resetProbability = 0.0001
# +---+------------------+
# | id|          pagerank|
# +---+------------------+
# |  a|0.7995415307794376|
# |  b|1.0668194897401873|
# |  c|1.0668194897401873|
# |  d|1.0668194897401873|
# +---+------------------+

# %% [markdown]
# ### Comment for task 3

# %% [markdown]
#  the difference between task 2 and task 3 is that we just removed the the link between c and a edges (can be seen in above script). by removing this link we can see that the pagerank for id a decreased while it increased for the rest ids.PageRank works by counting the number and quality of links to a page to determine a rough estimate of how important the website is.what I understood is that for task 2 the link to each letter (a,b,c,d) are equal and 2 for example, letter a and d link to b, and letter b and c link to a. However, in task 3 we removed the link from c to a and it decreased the quality of the any links to letter a. that is why  pagerank dropped for letter a, on the other hand the pagerank for the other letter raised. this is because of the probability of the other links increased. for example, in task 2. the probability of the links to letter b was 2/8 while now it is 2/7.

# %% [markdown]
# ## 2. Social network graph (remember setup code from start)

# %% [markdown]
# ## Task 1

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'

import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %%
#read graph edges(or arcs, lines) (multiple edges per vertex can exist)
lines = sc.textFile("698.edges")
edges = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row( src=int(p[0]), dst=int(p[1])) )
edges = sqlContext.createDataFrame(edges)

#read graph vertices(or nodes, points) (these are unique)
lines = sc.textFile("698.feat")
vertices = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row(id=int(p[0]), name="userid_"+p[0]) )
vertices = sqlContext.createDataFrame(vertices)    

# Create a GraphFrame
from graphframes import *
g = GraphFrame(vertices, edges)

#calculate pagerank
pagerank = g.pageRank(resetProbability=0.01, maxIter=20)
degrees = g.degrees

#join two results
result = pagerank.vertices.join(degrees,"id")
#print
result.select("name","pagerank","degree").orderBy("pagerank", ascending=False).show(100,False)

display(pagerank)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style class="pd_save is-viewer-good">
#     .node circle {
#         fill: #fff;
#         stroke: steelblue;
#         stroke-width: 1.5px;
#     }
#     .node {
#         font: 10px sans-serif;
#     }
#
#     .link {
#         fill: none;
#         stroke: #ccc;
#         stroke-width: 1.5px;
#     }
#
#     .graph-tree-form.form-inline .form-group {
#         margin-right: 10px;
#     }
#     .graph-tree-form.form-inline .form-group:last-child {
#         margin-left: 40px;
#     }
#     .graph-tree-form.form-inline input,
#     .graph-tree-form.form-inline select,
#     .graph-tree-form.form-inline button {
#         border-radius: 0;
#         margin: 0;
#         width: 100%;
#     }
#     .graph-error {
#         color: red;
#         font-weight: 500;
# ...

# %%
Image(filename='task2_1.PNG')

# %% [markdown]
# ## Task 2

# %% [markdown]
# PageRank works by counting the number and quality of links to a page to determine a rough estimate of how important the website is.it is hard to detect which user id is important by looking at the graph in task 1. However pagerank algorithm can provide  a proportional that gives us the importance for each user. as we did in Graphs and PageRank algorithm task 2&3 . that is why my opinion is that PageRank algorithm is better than just counting edges (graph degree) to find the most important vertices of the network. user 745 could be the important one by visual inspection but as i said due to the coarse of the graph its it is hard to determine it.

# %% [markdown]
# ## 3. Analyzing social network clustering (remember setup)

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'
import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %% [markdown]
# ## Task 1

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
import numpy as nb

#readn graph edges(or arcs, lines) (multiple edges per vertex can exist)
lines = sc.textFile("698.edges")
edges = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row( src=int(p[0]), dst=int(p[1])) )
edges = sqlContext.createDataFrame(edges)

#read graph vertices(or nodes, points) (these are unique)
lines = sc.textFile("698.feat")
vertices = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row(id=int(p[0]), name="userid_"+p[0] ,features=[int(x) for x in p[1:]] ))
vertices = sqlContext.createDataFrame(vertices)    

# Create a GraphFrame
from graphframes import *
g = GraphFrame(vertices, edges)

#calculate simple clustering with the label propagation clustering alg.
lpa = g.labelPropagation(maxIter=5)
nodes = lpa.select("id","label")

#plotting, generate unique colors for each group -----------------------
G = nx.DiGraph()
for x in g.edges.collect():
    G.add_edges_from([(x[0],x[1])], weight=1)
for x in lpa.select("id","label").rdd.map(lambda r: ( int(r[0]),int(r[1])) ).collect():
    G.add_node(x[0],label=x[1])
grouplabels = [list(x[1].values())[0] for x in G.nodes(True)]
node_texts = {node:node for node in G.nodes()};
cmap = plt.get_cmap('gist_rainbow')
uniqlabels = nb.unique(grouplabels)
randvals = nb.random.random_sample((len(uniqlabels),1))
colorlut = dict(zip(uniqlabels,randvals))  
gcolors = []
for x in grouplabels:
    gcolors.append(cmap(float(colorlut[x])))
positions=nx.spring_layout(G,k=0.1,scale=1.5,iterations=20)
nx.draw_networkx(G,positions, labels=node_texts, node_color = gcolors, node_size=500,arrows=False)
#plotting end ---
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
print('Number of clusters LPA generated is {}'.format(len(G)) )
# Out:
# Number of clusters LPA generated is 66

# %%
vertices.show()
# Out:
# +--------------------+---+----------+
# |            features| id|      name|
# +--------------------+---+----------+
# |[0, 0, 0, 0, 0, 0...|810|userid_810|
# |[0, 0, 0, 0, 0, 0...|857|userid_857|
# |[0, 0, 0, 0, 0, 0...|811|userid_811|
# |[0, 0, 0, 0, 0, 0...|858|userid_858|
# |[0, 0, 0, 0, 1, 1...|859|userid_859|
# |[0, 0, 0, 0, 1, 0...|860|userid_860|
# |[0, 0, 0, 0, 0, 0...|769|userid_769|
# |[1, 0, 0, 0, 0, 0...|861|userid_861|
# |[0, 0, 0, 0, 0, 0...|840|userid_840|
# |[0, 0, 0, 0, 1, 1...|862|userid_862|
# |[0, 0, 0, 0, 0, 0...|863|userid_863|
# |[0, 0, 0, 0, 0, 0...|729|userid_729|
# |[0, 0, 0, 0, 0, 0...|864|userid_864|
# |[0, 0, 0, 0, 0, 0...|865|userid_865|
# |[0, 0, 0, 0, 0, 0...|866|userid_866|
# |[0, 0, 0, 0, 0, 0...|867|userid_867|
# |[0, 0, 0, 0, 0, 0...|697|userid_697|
# |[0, 0, 0, 0, 0, 1...|868|userid_868|
# |[0, 0, 0, 0, 0, 0...|869|userid_869|
# |[0, 0, 0, 0, 0, 0...|708|userid_708|
# +--------------------+---+----------+
# only showing top 20 rows

# %% [markdown]
# ## Task 2

# %%
#line code explodes features into key values and duplicates label and ids
from pyspark.sql.functions import posexplode
#remove zeros from features to make histogram plotting easier
res = lpa.select('id','label',posexplode(lpa.features)).filter("col>0")
display(res)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure2a64ee5e" class="pd_save" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#
#         </div>

# %% [markdown]
# ## Task 3

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
import numpy as nb

#readn graph edges(or arcs, lines) (multiple edges per vertex can exist)
lines = sc.textFile("698.edges")
edges = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row( src=int(p[0]), dst=int(p[1])) )
edges = sqlContext.createDataFrame(edges)

#read graph vertices(or nodes, points) (these are unique)
lines = sc.textFile("698.feat")
vertices = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row(id=int(p[0]), name="userid_"+p[0] ,features=[int(x) for x in p[1:]] ))
vertices = sqlContext.createDataFrame(vertices) 

lines = sc.textFile("698.featnames")
names = lines.map(lambda l: l.split(" ")). \
            map(lambda p: Row(id=int(p[0]), featname=p[1].split(";")[0]+"_"+str(p[3]) ))      
names = sqlContext.createDataFrame(names) 

new_RDD = res.join(names, names.id == res.pos)

display(new_RDD)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFigure9a5cfef9" class="pd_save" style="overflow-x:auto">
#
#
#                             <center><img style="max-width:initial !important" src="data:image/png;base64,..." class="pd_save"></center>
#
#
#                         <div>Some labels are not displayed because of a lack of space. Click on Stretch image to see them all</div>
#
#
#         </div>

# %%
new_RDD.show()
# Out:
# +---+-----+---+---+---------+---+
# | id|label|pos|col| featname| id|
# +---+-----+---+---+---------+---+
# |823|  747| 26|  1|gender_77| 26|
# |828|  747| 26|  1|gender_77| 26|
# |880|  747| 26|  1|gender_77| 26|
# |703|  747| 26|  1|gender_77| 26|
# |713|  747| 26|  1|gender_77| 26|
# |882|  878| 26|  1|gender_77| 26|
# |861|  878| 26|  1|gender_77| 26|
# |890|  747| 26|  1|gender_77| 26|
# |719|  747| 26|  1|gender_77| 26|
# |871|  870| 26|  1|gender_77| 26|
# |697|  747| 26|  1|gender_77| 26|
# |867|  873| 26|  1|gender_77| 26|
# |800|  747| 26|  1|gender_77| 26|
# |819|  747| 26|  1|gender_77| 26|
# |872|  873| 26|  1|gender_77| 26|
# |772|  747| 26|  1|gender_77| 26|
# |753|  747| 26|  1|gender_77| 26|
# |886|  878| 26|  1|gender_77| 26|
# |884|  747| 26|  1|gender_77| 26|
# |745|  747| 26|  1|gender_77| 26|
# +---+-----+---+---+---------+---+
# only showing top 20 rows

# %% [markdown]
# ## Task 4

# %% [markdown]
# I guess the pattern are quite prominent to read for example from the histogram featname gender_77 has 23 rows and it can also readable from provided histogram and all label groups form meaningful histograms for analysis

# %% [markdown]
# ## Task 5 comment below

# %%
uniqvals = new_RDD.select('label').distinct().rdd.map(lambda p: p[0]).collect()
new_RDD.persist() #looping queries following, store intermediate data
for x in uniqvals:
    print("Group: " + str(x) + "\n")
    ures = new_RDD.filter('label=' + str(x)).groupBy("featname").sum("col").sort("sum(col)",ascending=False).rdd.map(lambda p: (p[0],p[1])).take(10)
    print(ures)
    print('\n')
# Out:
# Group: 857
#
# [('gender_78', 4), ('locale_127', 4), ('education_341', 3), ('education_53', 2), ('education_22', 2), ('education_54', 2), ('work_154', 2), ('education_55', 1), ('work_157', 1), ('location_366', 1)]
#
#
# Group: 883
#
# [('gender_78', 1), ('locale_127', 1)]
#
#
# Group: 891
#
# [('gender_78', 1), ('location_359', 1), ('locale_126', 1)]
#
#
# Group: 870
#
# [('gender_78', 7), ('locale_127', 6), ('education_53', 4), ('work_140', 4), ('education_55', 3), ('work_157', 3), ('work_366', 3), ('location_366', 3), ('education_64', 2), ('education_71', 2)]
#
#
# Group: 747
#
# [('gender_77', 17), ('locale_127', 16), ('education_53', 14), ('locale_126', 14), ('education_55', 13), ('gender_78', 12), ('education_340', 10), ('location_359', 8), ('education_341', 7), ('hometown_359', 6)]
#
#
# Group: 892
#
# [('gender_78', 1), ('locale_127', 1), ('last_name_371', 1), ('first_name_356', 1), ('name_372', 1)]
#
#
# Group: 860
#
# ...

# %%
uniqvals
# Out:
# [857, 883, 891, 870, 747, 892, 860, 878, 873]

# %% [markdown]
# This code snippet gives us the number of each featname occurred in each label. in uniqvals we can understnad fromits name, this retrieves the unique labels which named as group. in ures function we are trying to find the number of each featnames occured in each label. for example, for label(group) 857 the gender_78 appears 4 times, locale_127 appears 4 times and  group 857 appears 22 when we take the first 10 things.

# %% [markdown]
# # 4. Visualize flight routes data as graph (remember setup) (optional)

# %% [markdown]
# ## Task 1

# %%
import os
#download graphframes package
# !wget -q --show-progress http://dl.bintray.com/spark-packages/maven/graphframes/graphframes/0.8.1-spark2.4-s_2.12/:graphframes-0.8.1-spark2.4-s_2.12.jar -P /home/jovyan/
#tell to load graphframes and dependencies to the spark cluster for use
os.environ["PYSPARK_SUBMIT_ARGS"] = ' --packages graphframes:graphframes:0.8.1-spark2.4-s_2.12 --jars /home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-api_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.scala-lang_scala-reflect-2.12.0.jar,/home/jovyan/.ivy2/jars/com.typesafe.scala-logging_scala-logging-slf4j_2.12-2.1.2.jar,/home/jovyan/.ivy2/jars/org.slf4j_slf4j-api-1.7.7.jar,/home/jovyan/.ivy2/jars/graphframes_graphframes-0.8.1-spark2.4-s_2.12.jar pyspark-shell'


import pyspark
from pyspark.sql import *

try:
    sc = pyspark.SparkContext('local[*]',environment = {})
except:
    sc = sc
#create sqlcontext on the spark, enables the use of the SQL queries below
sqlContext = SQLContext(sc)

import pixiedust     #important, pixiedust must be initialized after pyspark, otherwise it just doesn't work right

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt
import numpy as nb

#readn graph edges(or arcs, lines) (multiple edges per vertex can exist)
lines = sc.textFile("routes.dat")
#split lines to items by comma
items = lines.map(lambda l: l.split(","))
#convert items on rows to dataframe Row
edges = items.map(lambda p: Row( dst=p[2], src=p[4]))
                                 
edges = sqlContext.createDataFrame(edges)


#read graph vertices(or nodes, points) (these are unique)
lines = sc.textFile("airports.dat")
vertices = lines.map(lambda l: l.split(",")). \
            map(lambda p: Row(id=(p[4])))
vertices = sqlContext.createDataFrame(vertices)    

# Create a GraphFrame
from graphframes import *
g = GraphFrame(vertices, edges)
display(g)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style class="pd_save is-viewer-good">
#     .node circle {
#         fill: #fff;
#         stroke: steelblue;
#         stroke-width: 1.5px;
#     }
#     .node {
#         font: 10px sans-serif;
#     }
#
#     .link {
#         fill: none;
#         stroke: #ccc;
#         stroke-width: 1.5px;
#     }
#
#     .graph-tree-form.form-inline .form-group {
#         margin-right: 10px;
#     }
#     .graph-tree-form.form-inline .form-group:last-child {
#         margin-left: 40px;
#     }
#     .graph-tree-form.form-inline input,
#     .graph-tree-form.form-inline select,
#     .graph-tree-form.form-inline button {
#         border-radius: 0;
#         margin: 0;
#         width: 100%;
#     }
#     .graph-error {
#         color: red;
#         font-weight: 500;
# ...

# %%
Image(filename='task4_1.PNG')
